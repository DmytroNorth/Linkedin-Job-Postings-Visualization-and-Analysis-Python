# %% [markdown]
#  ![linkedin-data-analyst-canada](img/linkedin-dataanalyst.png)
#
#  ![linkedin-data-analyst-canada-scrolldown](/img/linkedin-dataanalyst-scrolldown.png)
#
#  ![linkedin-data-analyst-canada-scrolldown](/linkedin-dataanalyst-scrolldown.png)
#
#  ![linkedin-data-analyst-canada-scrolldown](linkedin-dataanalyst-scrolldown.png)
#
#  ![linkedin-data-analyst-canada](img/linkedin-dataanalyst.jpeg)
#
#  ![linkedin-data-analyst-canada-scrolldown](/img/linkedin-dataanalyst-scrolldown.jpeg)
#
#  ![linkedin-data-analyst-canada-scrolldown](/linkedin-dataanalyst-scrolldown.jpeg)
#
#  ![linkedin-data-analyst-canada-scrolldown](linkedin-dataanalyst-scrolldown.jpeg)
#
#   ![linkedin-data-analyst-canada](img/linkedin-dataanalyst.png)
#
#    ![linkedin-data-analyst-canada-scrolldown](/img/linkedin-dataanalyst-scrolldown.png)
#
#   ![linkedin-data-analyst-canada-scrolldown](/linkedin-dataanalyst-scrolldown.png)
#
#   ![linkedin-data-analyst-canada-scrolldown](linkedin-dataanalyst-scrolldown.png)
#
#   ![linkedin-data-analyst-canada](img/linkedin-dataanalyst.jpeg)
#
#   ![linkedin-data-analyst-canada-scrolldown](/img/linkedin-dataanalyst-scrolldown.jpeg)
#
#   ![linkedin-data-analyst-canada-scrolldown](/linkedin-dataanalyst-scrolldown.jpeg)
#
#   ![linkedin-data-analyst-canada-scrolldown](linkedin-dataanalyst-scrolldown.jpeg)
#
#
#  ![linkedin-data-analyst-canada](img\linkedin-dataanalyst.png)
#
#  ![linkedin-data-analyst-canada-scrolldown](\img\linkedin-dataanalyst-scrolldown.png)
#
#  ![linkedin-data-analyst-canada-scrolldown](\linkedin-dataanalyst-scrolldown.png)
#
#  ![linkedin-data-analyst-canada-scrolldown](linkedin-dataanalyst-scrolldown.png)
#
#  ![linkedin-data-analyst-canada](img\linkedin-dataanalyst.jpeg)
#
#  ![linkedin-data-analyst-canada-scrolldown](\img\linkedin-dataanalyst-scrolldown.jpeg)
#
#  ![linkedin-data-analyst-canada-scrolldown](\linkedin-dataanalyst-scrolldown.jpeg)
#
#  ![linkedin-data-analyst-canada-scrolldown](linkedin-dataanalyst-scrolldown.jpeg)
